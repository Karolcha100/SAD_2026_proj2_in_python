# %%
import numpy as np
import pandas as pd

RANDOM_STATE = 42

# %%
df_train = pd.read_csv(f"data-01-processed/lgb_regression_train.csv", index_col=[0])

df_train
# Out:
#      temp  atemp    hum   wind  wcond  temp_sq     hum_sq   wind_sq  \
# 1     9.1   13.2  79.78  10.43      2    82.81  6364.8484  108.7849
# 2     9.9   12.7  68.91  16.16      2    98.01  4748.5881  261.1456
# 3     3.1    4.5  43.29  16.14      1     9.61  1874.0241  260.4996
# 4     3.2    5.6  58.45  10.42      1    10.24  3416.4025  108.5764
# 5     4.3    6.5  43.26  12.15      1    18.49  1871.4276  147.6225
# ..    ...    ...    ...    ...    ...      ...        ...       ...
# 361   8.3   11.4  75.49  12.25      2    68.89  5698.7401  150.0625
# 362   7.3    9.0  49.89  19.11      1    53.29  2489.0121  365.1921
# 363   5.2    8.2  56.84   7.76      1    27.04  3230.7856   60.2176
# 364   7.8   10.9  63.03   8.73      1    60.84  3972.7809   76.2129
# 365  11.8   15.7  60.97  14.31      1   139.24  3717.3409  204.7761
#
#      temp_x_hum  temp_x_wind  ...  weekend  dayofyear  quarter     sin_doy_1  \
# ...
