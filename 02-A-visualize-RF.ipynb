# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import pickle

# %%
df_res_a = pd.read_csv(f"params-random-forest/random_forest_4.csv", index_col=[0])

# %%
df_res_a.sort_values("val_rmse_mean").iloc[:10]
# Out:
#     max_depth max_features  min_samples_leaf  min_samples_split  n_estimators  \
# 8          21         sqrt                 1                  4           252
# 20         23         sqrt                 1                  4           252
# 32         25         sqrt                 1                  4           252
# 11         21         sqrt                 1                  4           255
# 26         24         sqrt                 1                  4           252
# 6          21         sqrt                 1                  4           250
# 23         23         sqrt                 1                  4           255
# 7          21         sqrt                 1                  4           251
# 18         23         sqrt                 1                  4           250
# 14         22         sqrt                 1                  4           252
#
#     train_rmse_mean  train_rmse_std  val_rmse_mean  val_rmse_std
# ...

# %%
df_res_b = pd.read_csv(f"params-random-forest/random_forest_5.csv", index_col=[0])

# %%
df_res_b.sort_values("val_rmse_mean").iloc[:10]
# Out:
#     max_depth max_features  min_samples_leaf  min_samples_split  n_estimators  \
# 9          21         sqrt                 1                  4           252
# 23         23         sqrt                 1                  4           252
# 37         25         sqrt                 1                  4           252
# 30         24         sqrt                 1                  4           252
# 16         22         sqrt                 1                  4           252
# 2          20         sqrt                 1                  4           252
# 6          20         sqrt                 1                  8           252
# 13         21         sqrt                 1                  8           252
# 27         23         sqrt                 1                  8           252
# 41         25         sqrt                 1                  8           252
#
#     train_rmse_mean  train_rmse_std  val_rmse_mean  val_rmse_std
# ...
